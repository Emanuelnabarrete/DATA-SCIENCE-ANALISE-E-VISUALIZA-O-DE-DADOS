# %% [markdown]
# <a href="https://colab.research.google.com/github/Emanuelnabarrete/DATA-SCIENCE-ANALISE-E-VISUALIZA-O-DE-DADOS/blob/main/Visualizacao_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
notas = pd.read_csv("ratings.csv")

# %%
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# **Alterando nome das colunas**

# %%
notas.columns = ["UsuarioID" , "FilmeID", "Nota", "Momento"]

# %%
notas
# Out:
#         UsuarioID  FilmeID  Nota     Momento
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# **Media**

# %%
notas.Nota.mean()
# Out:
# 3.501556983616962

# %%
notas.Nota.value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: Nota, dtype: int64

# %% [markdown]
# **Plot pandas**

# %%
notas_avaliacao = notas.Nota.value_counts().plot(kind = "bar")

# %% [markdown]
# **Mediana**}

# %%
print(notas.Nota.median())
# Out:
# 3.5

# %% [markdown]
# **Media**

# %%
print(notas.Nota.mean())
# Out:
# 3.501556983616962

# %% [markdown]
# **Descricao numerica dos dados**

# %%
notas.Nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: Nota, dtype: float64

# %%
sns.boxplot(notas.Nota)
# Out:
# <Axes: >

# %% [markdown]
# ## Analise exploratioria

# %%
filmes= pd.read_csv("movies.csv")

# %%
filmes
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
filmes.columns = ["FilmeID" , "Titulo", "genero"]

# %%
filmes.head()
# Out:
#    FilmeID                              Titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# **Fazendo uma pergunta para o df**

# %%
notas.query("FilmeID==1").Nota.head(10)
# Out:
# 0       4.0
# 516     4.0
# 874     4.5
# 1434    2.5
# 1667    4.5
# 1772    3.5
# 2274    4.0
# 3219    3.5
# 4059    3.0
# 4879    5.0
# Name: Nota, dtype: float64

# %%
notas.head()
# Out:
#    UsuarioID  FilmeID  Nota    Momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.query("FilmeID==1").Nota.mean()#Toy Story
# Out:
# 3.9209302325581397

# %% [markdown]
# **Groupby** = Agrupa pelo filmeId a media de todas as colunas

# %%
notas.groupby("FilmeID").mean()
# Out:
#           UsuarioID      Nota       Momento
# FilmeID
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
media_por_filme =pd.DataFrame(notas.groupby("FilmeID").Nota.mean())

# %%
media_por_filme
# Out:
#              Nota
# FilmeID
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# ...           ...
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193587   3.500000
# 193609   4.000000
#
# [9724 rows x 1 columns]

# %% [markdown]
# **Histograma do pandas**

# %%
media_por_filme.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Boxplox seaborn**

# %%
sns.boxplot(media_por_filme)
# Out:
# <Axes: >

# %%
media_por_filme.describe()
# Out:
#               Nota
# count  9724.000000
# mean      3.262448
# std       0.869874
# min       0.500000
# 25%       2.800000
# 50%       3.416667
# 75%       3.911765
# max       5.000000

# %% [markdown]
#  Pelo **matplotlib** podemos atribuir titulos dentre outras coisas no grafico

# %%
plt.title("Medias por filme")
sns.histplot(media_por_filme)
# Out:
# <Axes: title={'center': 'Medias por filme'}, ylabel='Count'>

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
linguas = movies.original_language.unique()

# %%
linguas
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
qnt_linguas = movies.original_language.value_counts()

# %%
qnt_linguas
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
df_linguas = qnt_linguas.to_frame().reset_index()
df_linguas.columns = ["Linguas" , "Total"]
df_linguas.head()
# Out:
#   Linguas  Total
# 0      en   4505
# 1      fr     70
# 2      es     32
# 3      zh     27
# 4      de     27

# %% [markdown]
# Grafico barras do seaborn || dizer o x , y , e dados(data) para cria-lo

# %%
sns.barplot(x = "Linguas" , y = "Total", data = df_linguas)#*****************************
# Out:
# <Axes: xlabel='Linguas', ylabel='Total'>

# %% [markdown]
# Grafico de barras mais comum - > trazer o x, o tipo que ira realiza (kind) , os dados (data) || forma mais facil de usar

# %%
sns.catplot(x="original_language", kind="count", data=movies)

# %% [markdown]
# Grafico de torta do **matplotlib**

# %%
plt.pie(df_linguas["Total"], labels =df_linguas['Linguas'])

# %%
total_lingua = movies["original_language"].value_counts()

# %%
total_lingua
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %% [markdown]
# **.loc[" "]** localiza e traz o total de todos os valores que estao dentro

# %%
en = total_lingua.loc["en"]

# %%
en
# Out:
# 4505

# %%
rest = (total_lingua.sum()) - en

# %%
print(en , rest)
# Out:
# 4505 298

# %% [markdown]
# Criando dicionario - > Criando df a partir dele

# %%
dados= {
        "Linguas" : ["ingles" , "outros"],
        "total" : [en , rest]
        }

dados = pd.DataFrame(dados)
dados
# Out:
#   Linguas  total
# 0  ingles   4505
# 1  outros    298

# %% [markdown]
# plotando dicionario

# %%
sns.barplot(x = "Linguas" , y = "total" , data = dados)
# Out:
# <Axes: xlabel='Linguas', ylabel='total'>

# %% [markdown]
# not_en = filmes - > linguas(original_language) -> (linguas diferente de ingles) - > so as linguas - > liguas categorizadas por quantidade de vezes que apareceu
#
# total_sem_ingles = total de filmes sem o ingles ( trago o df )

# %%
not_en = movies.query("original_language != 'en'").original_language.value_counts()
total_sem_en = movies.query("original_language != 'en'")

# %% [markdown]
# sns.catplot(x = original_language( linguas ) , kind  = "count" ( quantas vezes apareceu) , data = dados (total_sem_ingles)
#
#
#
#
#
#
#
# aspect = tamanho (semelhante a largura) | order (pondo em ordem) = **not_en** com ele podemos la em cima tirar a categorica e trazer para ca (plot) | palette = Cores

# %%
sns.catplot(x="original_language", kind="count", data= total_sem_en, aspect = 2, order =not_en.index , palette = "PuOr")

# %%
filmes.head()
# Out:
#    FilmeID                              Titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# **Media**

# %%
notas_th = notas.query("FilmeID ==1")
notas_ju = notas.query("FilmeID ==2")

# %%
print(len(notas_th))
# Out:
# 215

# %%
print(len(notas_ju))
# Out:
# 110

# %%
media_th = notas_th.Nota.mean()
media_ju = notas_ju.Nota.mean()
print(f"Media nota Toy Story {round(media_th, 2)}")
print(f"Media nota Jumanji {round(media_ju, 2)}")
# Out:
# Media nota Toy Story 3.92
# Media nota Jumanji 3.43

# %% [markdown]
# **Mediana**

# %%
print(notas_th.Nota.median())
print(notas_ju.Nota.median())
# Out:
# 4.0
# 3.5

# %% [markdown]
# Importando e usando numpy(arrays)

# %%
import numpy as np
filme1 = np.append(np.array([2.5] *10), np.array([3.5]*10))
filme2 = np.append(np.array([5] *10), np.array([1]*10))

# %%
print(filme1.mean())
print(filme2.mean())
# Out:
# 3.0
# 3.0

# %%
print(np.median(filme1))
print(np.median(filme2))
# Out:
# 3.0
# 3.0

# %%
sns.histplot(filme1)
sns.histplot(filme2)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.distplot([filme1, filme2])
# Out:
# <ipython-input-172-1bb2d8395d1b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([filme1, filme2])
# <Axes: ylabel='Density'>

# %%
sns.boxplot([filme1, filme2])
# Out:
# <Axes: >

# %%
plt.boxplot([filme1, filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a0867c09db0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a0867818460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a0867c09570>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7a08678189a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7a0867818c40>,
# ...
#  'means': []}

# %%
sns.boxplot(y = notas_th.Nota)
# Out:
# <Axes: ylabel='Nota'>

# %%
sns.boxplot(y = notas_ju.Nota)
# Out:
# <Axes: ylabel='Nota'>

# %%
sns.boxplot(x = "FilmeID" , y = "Nota" , data = notas.query("FilmeID in [1,2]"))
# Out:
# <Axes: xlabel='FilmeID', ylabel='Nota'>

# %% [markdown]
# Usando desvio de padrao nos dados

# %%
desvio_pa_th = notas_th.Nota.std()
desvio_pa_ju = notas_ju.Nota.std()

print(desvio_pa_ju, desvio_pa_th)
# Out:
# 0.8817134921476455 0.8348591407114047

# %%
print(np.std(filme1) , np.std(filme2))
# Out:
# 0.5 2.0
